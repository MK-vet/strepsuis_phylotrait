# %% [markdown]
# # strepsuis-phylotrait - Google Colab Demonstration

# %%
# !pip install git+https://github.com/MK-vet/strepsuis-phylotrait.git

# %%
# !strepsuis-phylotrait --version

# %%
# !strepsuis-phylotrait --help
